# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_columns",100)

# %%
path="https://raw.githubusercontent.com/kshedden/statswpy/master/NHANES/merged/nhanes_2015_2016.csv"
df = pd.read_csv(path)

# %%
df.head(3)
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0       1.0       5.0       1.0         2  134671.37        1       125
# 1       2.0       3.0       3.0         1   24328.56        1       125
# 2       1.0       3.0       1.0         2   12400.01        1       131
#
#    INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0      4.39   128.0    70.0   124.0    64.0   94.8  184.5    27.8    43.3
# 1      1.32   146.0    88.0   140.0    88.0   90.4  171.4    30.8    38.0
# 2      1.51   138.0    46.0   132.0    44.0   83.4  170.1    28.8    35.6
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
df.columns
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210'],
#       dtype='object')

# %%
keep=[ 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
       'BMXWAIST']

# %%
df[keep].head()
# Out:
#    BMXWT  BMXHT  BMXBMI  BMXLEG  BMXARML  BMXARMC  BMXWAIST
# 0   94.8  184.5    27.8    43.3     43.6     35.9     101.1
# 1   90.4  171.4    30.8    38.0     40.0     33.2     107.9
# 2   83.4  170.1    28.8    35.6     37.0     31.0     116.5
# 3  109.8  160.9    42.4    38.5     37.7     38.3     110.1
# 4   55.2  164.9    20.3    37.4     36.0     27.2      80.4

# %%
keep= [column for column in df.columns if "BM" in column]

# %%
df[keep].head()
# Out:
#    BMXWT  BMXHT  BMXBMI  BMXLEG  BMXARML  BMXARMC  BMXWAIST
# 0   94.8  184.5    27.8    43.3     43.6     35.9     101.1
# 1   90.4  171.4    30.8    38.0     40.0     33.2     107.9
# 2   83.4  170.1    28.8    35.6     37.0     31.0     116.5
# 3  109.8  160.9    42.4    38.5     37.7     38.3     110.1
# 4   55.2  164.9    20.3    37.4     36.0     27.2      80.4

# %%
df.loc[:,keep].head()
# Out:
#    BMXWT  BMXHT  BMXBMI  BMXLEG  BMXARML  BMXARMC  BMXWAIST
# 0   94.8  184.5    27.8    43.3     43.6     35.9     101.1
# 1   90.4  171.4    30.8    38.0     40.0     33.2     107.9
# 2   83.4  170.1    28.8    35.6     37.0     31.0     116.5
# 3  109.8  160.9    42.4    38.5     37.7     38.3     110.1
# 4   55.2  164.9    20.3    37.4     36.0     27.2      80.4

# %%
index_bool = np.isin(df.columns,keep) #Where are the points where all the keep values are in the column names

# %%
index_bool
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True,  True,  True,  True,  True,  True,  True,
#        False])

# %%
df.iloc[:,index_bool].head()
# Out:
#    BMXWT  BMXHT  BMXBMI  BMXLEG  BMXARML  BMXARMC  BMXWAIST
# 0   94.8  184.5    27.8    43.3     43.6     35.9     101.1
# 1   90.4  171.4    30.8    38.0     40.0     33.2     107.9
# 2   83.4  170.1    28.8    35.6     37.0     31.0     116.5
# 3  109.8  160.9    42.4    38.5     37.7     38.3     110.1
# 4   55.2  164.9    20.3    37.4     36.0     27.2      80.4

# %%
waist_median = df['BMXWAIST'].median()

# %%
waist_median
# Out:
# 98.3

# %%
pd.Series.median(df['BMXWAIST']) #another way
# Out:
# 98.3

# %%
condition1 = df['BMXWAIST'] > waist_median
condition2 = df['BMXLEG'] < 32
condition3 = df['BMXARML'] > 34

# %%
df[condition1&condition2&condition3].head()
# Out:
#       SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 52   83832     2.0     1.0     4.0       2         2        50         1
# 105  83920     2.0     1.0     NaN       2         2        68         1
# 148  83990     2.0     2.0     NaN       2         2        79         1
# 277  84208     2.0     2.0     NaN       2         2        67         1
# 483  84569     1.0     NaN     3.0       2         2        55         1
#
#      DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ  WTINT2YR  SDMVPSU  SDMVSTRA  \
# 52        2.0       1.0       4.0         5  11709.11        1       121
# 105       1.0       1.0       1.0         7   9719.31        1       121
# 148       2.0       1.0       1.0         2  15028.85        1       128
# 277       1.0       1.0       2.0         1   8842.35        1       128
# 483       1.0       5.0       1.0         3  15060.77        1       127
#
#      INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
df.loc[condition1&condition2&condition3,:].head() #same as above
# Out:
# Empty DataFrame
# Columns: [SEQN, ALQ101, ALQ110, ALQ130, SMQ020, RIAGENDR, RIDAGEYR, RIDRETH1, DMDCITZN, DMDEDUC2, DMDMARTL, DMDHHSIZ, WTINT2YR, SDMVPSU, SDMVSTRA, INDFMPIR, BPXSY1, BPXDI1, BPXSY2, BPXDI2, BMXWT, BMXHT, BMXBMI, BMXLEG, BMXARML, BMXARMC, BMXWAIST, HIQ210]
# Index: []

# %%
df.loc[:,'BMXWAIST'].values
# Out:
# array([101.1, 107.9, 116.5, ...,   nan,  98.9,  72.5])

# %%
df.columns.get_loc('BMXWAIST')
# Out:
# 26

# %%
df.iloc[:,26].head()
# Out:
# 0    101.1
# 1    107.9
# 2    116.5
# 3    110.1
# 4     80.4
# Name: BMXWAIST, dtype: float64

# %%
df.iloc[1:3, df.columns.get_loc('BMXWAIST')] = 77

# %%
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0       1.0       5.0       1.0         2  134671.37        1       125
# 1       2.0       3.0       3.0         1   24328.56        1       125
# 2       1.0       3.0       1.0         2   12400.01        1       131
# 3       1.0       5.0       6.0         1  102718.00        1       131
# 4       1.0       4.0       3.0         5   17627.67        2       126
#
#    INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %% [markdown]
# # Unit TESTING

# %%
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0       1.0       5.0       1.0         2  134671.37        1       125
# 1       2.0       3.0       3.0         1   24328.56        1       125
# 2       1.0       3.0       1.0         2   12400.01        1       131
# 3       1.0       5.0       6.0         1  102718.00        1       131
# 4       1.0       4.0       3.0         5   17627.67        2       126
#
#    INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
df.columns.get_loc('BPXSY1')
# Out:
# 16

# %%
value = df.iloc[0:101, 16].mean()
value
# Out:
# 124.83333333333333

# %%
df[df.RIDAGEYR > 60].iloc[0:101,16].mean()
# Out:
# 136.0

# %%
df[df.RIDAGEYR > 60].loc[0:6,'BPXSY1'].head()
# Out:
# 0    128.0
# 2    138.0
# 5    116.0
# Name: BPXSY1, dtype: float64

# %%
df[df.RIDAGEYR > 60].iloc[0:6,16].head()
# Out:
# 0     128.0
# 2     138.0
# 5     116.0
# 13    124.0
# 14    132.0
# Name: BPXSY1, dtype: float64
